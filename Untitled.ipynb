# %%
import Calculator_1

print(Calculator_1.add(5,6))
print(Calculator_1.sub(10,5))
# Out:
# 11
# 5

# %%
print(Calculator_1.__file__)
# Out:
# C:\Users\kunal\PythonLearning\Calculator_1.py

# %%
dir(Calculator_1)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'add',
#  'sub']
